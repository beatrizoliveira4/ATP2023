# %%
### TPC5

sala1 = (150, [], "Twilight")
sala2 = (200, [], "Hannibal")
cinema1 = [sala1, sala2]


Menu = print('''
        Menu:
        1. Filmes em exibição
        2. Disponibilidade de Lugares: Insere o lugar que pretendes ocupar
        3. Lugares vendidos
        4. Filme em exibição + Lugares disponiveis 
        5. Inserir Sala ao Cinema
        6. Sair
       ''')   

n = str(input("Seja bem-vindo ao cinema VOZ!"))   
opc = int(input("Selecione a opção do menu que pretende efetuar! Se quiser encerrar o menu, selecione a opção 6."))



def listar(cinema):
    print ("------- FILMES EM EXIBIÇÃO -------")
    lista = []
    for sala in cinema:
        lista.append(sala[2])

    return lista



def disponivel(cinema, filme, lugar):
    res = True
    for sala in cinema:
        if filme == sala[2]:
            if lugar in sala[1]:
                res = False

        return res
   
    

def venderbilhete (cinema, filme, lugar):
     if disponivel(cinema, filme, lugar) == cond:
        for sala in cinema:
            if filme == sala[2]:
                sala[1].append(lugar)

     return cinema



def listardisponibilidades(cinema):
    l=[]
    for sala in cinema:
        disp = (sala[2],sala[0]-len(sala[1]))
        l.append(disp)

    return l



def inserirsala(cinema, sala):
    if sala not in cinema:
        cinema.append(sala)
    return cinema



while opc != 6:

    if opc == 1:
        print(listar(cinema1))
        opc = int(input("Selecione a opção do menu que pretende efetuar! Se quiser encerrar o menu, selecione a opção 6."))


    if opc == 2:
        cinema = str(input("Escolha o cinema"))
        filme = str(input("Qual é o filme que quer ver"))
        lugar = str(input("Escolha o lugar"))

        cond = disponivel(cinema1, filme, lugar)

        if cond:
            print("O lugar selecionado está disponível")

        else:
            print("O lugar selecionado não está disponível")
        opc = int(input("Selecione a opção do menu que pretende efetuar! Se quiser encerrar o menu, selecione a opção 6."))

    if opc == 3:
        cinema = str(input("Escolha o cinema"))
        filme = str(input("Qual é o filme que quer ver"))
        lugar = str(input("Escolha o lugar"))

        print(venderbilhete(cinema1, filme, lugar))
        opc = int(input("Selecione a opção do menu que pretende efetuar! Se quiser encerrar o menu, selecione a opção 6."))

 
    if opc == 4:
        print(listardisponibilidades(cinema1))
        opc = int(input("Selecione a opção do menu que pretende efetuar! Se quiser encerrar o menu, selecione a opção 6."))


    if opc == 5:
    
        filme = str(input("Insira o filme que estará em exibição na sala"))
        num_lugares = int(input("Insira o número de lugares disponiveis na sala"))
        num_vendidos = int(input("Quantos lugares já estão vendidos?"))
       
          
        sala3 = (num_lugares,num_vendidos,filme)
        print(inserirsala(cinema1,sala3))
        opc = int(input("Selecione a opção do menu que pretende efetuar! Se quiser encerrar o menu, selecione a opção 6."))
    

print("Muito Obrigada! Volte Sempre.")
